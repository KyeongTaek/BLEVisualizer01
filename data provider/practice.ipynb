# %%
from Data_provider import get_processed_data
get_processed_data()
# Out:
# 전체 데이터: 7680행
# GPS 필터 후: 7611행
# 유효 MAC 필터 후: 7611행
#
# 라디오맵 위치(RP) 수: 98개
# 사용 센서 수: 5개
#
# 라디오맵 미리보기:
#                   88:A2:9E:9B:5E:6A  B8:27:EB:D3:40:06  D8:3A:DD:79:8E:BF  D8:3A:DD:79:8F:80  D8:3A:DD:C1:88:BD
# lat_r   lon_r
# 36.6255 127.4571         -74.882353         -79.038462         -67.894737         -90.100000         -76.857143
# 36.6282 127.4573                NaN         -92.250000         -93.000000         -87.000000                NaN
# 36.6285 127.4568         -73.785714         -79.625000         -78.000000         -78.000000                NaN
#         127.4569         -84.000000         -73.692308                NaN         -86.000000                NaN
# 36.6287 127.4606         -81.244240         -80.466480         -73.473282         -78.813559         -73.000000
#
# 학습 데이터: 78개 위치
# 테스트 데이터: 20개 위치
#
# CSV 저장 완료: X_train / X_test / y_train / y_test
